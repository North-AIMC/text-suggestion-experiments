# %%
import pandas as pd
df = pd.read_csv('../results/2020-08-25-07-26-53.csv')
df.head(30)
# Out:
#                                     pipe group  total_chars  total_clicks  \
# 0                             1_NullTest     +        10819         10819
# 1                             1_NullTest     -        10819         10819
# 2                             1_NullTest     0        10819         10819
# 3                             2_BiasTest     +        10819         10819
# 4                             2_BiasTest     -        10819         10819
# 5                             2_BiasTest     0        10819         10819
# 6                             3_TimeTest     +        10819         10819
# 7                             3_TimeTest     -        10819         10819
# 8                             3_TimeTest     0        10819         10819
# 9                    4_BiasedCompletions     +        10819          8269
# 10                   4_BiasedCompletions     -        10819          8288
# 11                   4_BiasedCompletions     0        10819         10819
# ...
